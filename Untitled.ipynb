# %%
import pandas as pd

# %%
brew = "brewerydbAPI/Output/brewerydb_final.csv"

# %%
brewdb = pd.read_csv(brew)
brewdb.head()
# Out:
#         Brewery Name        City       State        Country  Year Established  \
# 0  4 Seasons Brewery      Lapeer    Michigan  UNITED STATES              2014
# 1   40 North Brewing     Boulder    Colorado  UNITED STATES              2011
# 2  4KD Crick Brewery    Defiance        Ohio  UNITED STATES              2016
# 3     7 Mile Brewery  Rio Grande  New Jersey  UNITED STATES              2016
# 4      810 Meadworks      Medina    New York  UNITED STATES              2014
#
#   Still in Business? Closed?
# 0                  Y       N
# 1                  Y       N
# 2                  Y       N
# 3                  Y       N
# 4                  Y       N

# %%
brew_db = brewdb.groupby(["State"])
brew_db.count().head()
# Out:
#             Brewery Name  City  Country  Year Established  Still in Business?  \
# State
# Alabama                5     5        5                 5                   5
# Alaska                 2     2        2                 2                   2
# Arizona               10    10       10                10                  10
# Arkansas               1     1        1                 1                   1
# California            70    70       70                70                  70
#
#             Closed?
# State
# Alabama           5
# Alaska            2
# Arizona          10
# Arkansas          1
# California       70

# %%
brew_c = brewdb.loc[brewdb["Closed?"] == "Y"]
brew_c
# Out:
#                             Brewery Name              City           State  \
# 33                             Beer Army          New Bern  North Carolina
# 36                      Beryl's Beer Co.            Denver        Colorado
# 47                            Bravo Zulu    N Williamsburg        Michigan
# 111                       Ursula Brewery            Aurora        Colorado
# 127                   Beach City Brewery  Huntington Beach      California
# 138          Rock Bridge Brewing Company          Columbia        Missouri
# 139                Bog Water Brewing Co.          Westport      Washington
# 157                    Little Egypt Beer               Ava        Illinois
# 160                Cobra Brewing Company        Lewisville           Texas
# 167                Owl's Orchard Brewery       Queen Creek         Arizona
# 177                Sanctuary Brewing Co.      Indianapolis         Indiana
# ...

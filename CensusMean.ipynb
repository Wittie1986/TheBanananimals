# %%
import pandas as pd
import matplotlib as mp
import numpy as np

# %%
cen = "census_df_clean.csv"
brew = "brewerydbAPI/Output/brewerydb_final.csv"

# %%
Cen = pd.read_csv(cen)
Brew = pd.read_csv(brew)

# %%
Cen.head(2000)
# Out:
#          State                  City  2010 POP  Median 2010  2011 POP  \
# 0      Alabama               Alabama   4785579        42081   4798649
# 1      Alabama        Abbeville city      2684        42081      2677
# 2      Alabama       Adamsville city      4516        42081      4502
# 3      Alabama          Addison town       751        42081       751
# 4      Alabama            Akron town       355        42081       345
# 5      Alabama        Alabaster city     31182        42081     31341
# 6      Alabama      Albertville city     21143        42081     21308
# 7      Alabama   Alexander City city     14930        42081     14889
# 8      Alabama       Aliceville city      2480        42081      2426
# 9      Alabama          Allgood town       622        42081       623
# 10     Alabama          Altoona town       937        42081       935
# 11     Alabama        Andalusia city      9026        42081      9071
# ...

# %%
cen_ = cennnn.groupby(["State"]).sum()
cen_.head()
# Out:
#              2010 POP  Median 2010   2011 POP  Median 2011   2012 POP  \
# State
# Alabama      12471791     46457424   12507158     47399136   12549162
# Alaska        2630861     23082787    2660445     23947858    2691702
# Arizona      24261551     11149008   24488383     11216192   24793522
# Arkansas     10659505     46060191   10726610     47094777   10769293
# California  142984867     65570991  144322487     66377664  145663478
#
#             Median 2012   2013 POP  Median 2013   2014 POP  Median 2014  \
# State
# Alabama        47648640   12588089     47751312   12622178     48036144
# Alaska         24261199    2713301     24553720    2712355     24924663
# Arizona        11106576   25073596     11000054   25421957     11034088
# Arkansas       47542863   10802114     47820864   10836370     48402672
# California     66127800  146940368     65798238  148307574     66223653
#
#              2015 POP  Median 2015   2016 POP  Median 2016   2017 POP  \
# State
# ...

# %%
mean = cen_.mean()
mean
# Out:
#                            2010 POP  Median 2010       2011 POP  Median 2011  \
# State
# Alabama                15617.529412      42081.0   15661.363801      42934.0
# Alaska                  7581.731988      66521.0    7666.988473      69014.0
# Arizona               109780.773756      50448.0  110807.162896      50752.0
# Arkansas                9087.387042      39267.0    9144.595055      40149.0
# California            132762.179201      60883.0  134004.166202      61632.0
# Colorado               27272.895803      56456.0   27651.759768      57685.0
# Connecticut            60172.259649      67740.0   60379.698246      69243.0
# Delaware               23829.145161      57599.0   24047.250000      59317.0
# District of Columbia  605040.000000      58526.0  620336.000000      61835.0
# Florida                68678.962578      47661.0   69596.089397      47827.0
# Georgia                23402.962810      49347.0   23640.202479      49736.0
# ...

# %%
dfmean = mean[["2010 POP", "2011 POP", "2012 POP", "2013 POP", "2014 POP", "2015 POP", "2016 POP", "2017 POP"]]
dfmean.head()
# Out:
#    2010 POP  2011 POP  2012 POP  2013 POP  2014 POP  2015 POP  2016 POP  \
# 0   4785579   4798649   4813946   4827660   4840037   4850858   4860545
# 1      2684      2677      2629      2612      2595      2587      2575
# 2      4516      4502      4479      4457      4437      4409      4376
# 3       751       751       744       743       740       734       734
# 4       355       345       345       341       337       335       332
#
#    2017 POP
# 0   4874747
# 1      2567
# 2      4347
# 3       728
# 4       332

# %%
dfPOP = mean[["Median 2010", "Median 2011", "Median 2012", "Median 2013", "Median 2014", "Median 2015", "Median 2016", "Median 2017"]]
dfPOP.head()
# Out:
#             Median 2010  Median 2011  Median 2012  Median 2013  Median 2014  \
# State
# Alabama         42081.0      42934.0      43160.0      43253.0      43511.0
# Alaska          66521.0      69014.0      69917.0      70760.0      71829.0
# Arizona         50448.0      50752.0      50256.0      49774.0      49928.0
# Arkansas        39267.0      40149.0      40531.0      40768.0      41264.0
# California      60883.0      61632.0      61400.0      61094.0      61489.0
#
#             Median 2015  Median 2016  Median 2017
# State
# Alabama         43623.0      44758.0      46472.0
# Alaska          72515.0      74444.0      76114.0
# Arizona         50255.0      51340.0      53510.0
# Arkansas        41371.0      42336.0      43813.0
# California      61818.0      63783.0      67169.0

# %%
mean.to_csv("CensusOutput/censusmean.csv",
                   encoding="utf-8", index=False, header=True)

# %%
dfmean.to_csv("CensusOutput/POPmean.csv",
                   encoding="utf-8", index=False, header=True)

# %%
dfPOP.to_csv("CensusOutput/MedianMean.csv",
                   encoding="utf-8", index=False, header=True)

# %%
# Import Dependencies

import pandas as pd
import numpy as np

# %%
# Define File Path for CSVs

brew1 = "Output/brewery_data_page001-014.csv"
brew2 = "Output/brewery_data_page015-029.csv"
brew3 = "Output/brewery_data_page030-044.csv"
brew4 = "Output/brewery_data_page045-059.csv"
brew5 = "Output/brewery_data_page060-074.csv"
brew6 = "Output/brewery_data_page075-089.csv"
brew7 = "Output/brewery_data_page090-104.csv"
brew8 = "Output/brewery_data_page105-119.csv"
brew9 = "Output/brewery_data_page120-134.csv"
brew10 = "Output/brewery_data_page135-149.csv"
brew11 = "Output/brewery_data_page150-164.csv"
brew12 = "Output/brewery_data_page165-179.csv"
brew13 = "Output/brewery_data_page180-194.csv"
brew14 = "Output/brewery_data_page195-209.csv"
brew15 = "Output/brewery_data_page210-224.csv"
brew16 = "Output/brewery_data_page225-239.csv"
brew17 = "Output/brewery_data_page240-254.csv"
brew18 = "Output/brewery_data_page255-260.csv"
brew19 = "Output/brewery_data_page261.csv"

# %%
# Read in CSVs

brewdf1 = pd.read_csv(brew1)
brewdf2 = pd.read_csv(brew2)
brewdf3 = pd.read_csv(brew3)
brewdf4 = pd.read_csv(brew4)
brewdf5 = pd.read_csv(brew5)
brewdf6 = pd.read_csv(brew6)
brewdf7 = pd.read_csv(brew7)
brewdf8 = pd.read_csv(brew8)
brewdf9 = pd.read_csv(brew9)
brewdf10 = pd.read_csv(brew10)
brewdf11 = pd.read_csv(brew11)
brewdf12 = pd.read_csv(brew12)
brewdf13 = pd.read_csv(brew13)
brewdf14 = pd.read_csv(brew14)
brewdf15 = pd.read_csv(brew15)
brewdf16 = pd.read_csv(brew16)
brewdf17 = pd.read_csv(brew17)
brewdf18 = pd.read_csv(brew18)
brewdf19 = pd.read_csv(brew19)

# %%
# Merge CSVs

brewerydf = pd.concat((brewdf1, brewdf2, brewdf3, brewdf4, brewdf5, brewdf6, brewdf7, brewdf8,
                       brewdf9, brewdf10, brewdf11, brewdf12, brewdf13, 
                        brewdf14, brewdf15, brewdf16, brewdf17, brewdf18, 
                        brewdf19), join="outer")
brewerydf.head()
# Out:
#                    Brewery Name            City       State        Country  \
# 0             4 Seasons Brewery          Lapeer    Michigan  UNITED STATES
# 1              40 North Brewing         Boulder    Colorado  UNITED STATES
# 2             4KD Crick Brewery        Defiance        Ohio  UNITED STATES
# 3  Karl Strauss Brewing Company       San Diego  California  UNITED STATES
# 4                7 Cent Brewery  Gisborne South    Victoria      AUSTRALIA
#
#    Year Established Still in Business? Closed?
# 0              2014                  Y       N
# 1              2011                  Y       N
# 2              2016                  Y       N
# 3              1989                  Y       N
# 4              2012                  Y       N

# %%
## Clean up the Data Frame

# Initial count
brewerydf.count()
# Out:
# Brewery Name          1065
# City                  1065
# State                 1065
# Country               1065
# Year Established      1065
# Still in Business?    1065
# Closed?               1065
# dtype: int64

# %%
# Remove non-USA Breweries

usabrewerydf = brewerydf.loc[(brewerydf["Country"] == "UNITED STATES")]
usabrewerydf.count()
# Out:
# Brewery Name          835
# City                  835
# State                 835
# Country               835
# Year Established      835
# Still in Business?    835
# Closed?               835
# dtype: int64

# %%
# Remove Breweries before 2009

brewerydf2009 = usabrewerydf.loc[(usabrewerydf["Year Established"] >= 2009)]
brewerydf2009.count()
# Out:
# Brewery Name          563
# City                  563
# State                 563
# Country               563
# Year Established      563
# Still in Business?    563
# Closed?               563
# dtype: int64

# %%
# Replace "null" with NaN values

#brewerydfnull = brewerydf2009.replace(['null'], np.nan)
#brewerydfnull.count()

# %%
# Drop all rows with missing information

#cleanbrewerydf = brewerydfnull.dropna(axis=0, how='any')
#cleanbrewerydf.count()

# %%
final_df = brewerydf2009
final_df.head()
# Out:
#         Brewery Name        City       State        Country  Year Established  \
# 0  4 Seasons Brewery      Lapeer    Michigan  UNITED STATES              2014
# 1   40 North Brewing     Boulder    Colorado  UNITED STATES              2011
# 2  4KD Crick Brewery    Defiance        Ohio  UNITED STATES              2016
# 6     7 Mile Brewery  Rio Grande  New Jersey  UNITED STATES              2016
# 7      810 Meadworks      Medina    New York  UNITED STATES              2014
#
#   Still in Business? Closed?
# 0                  Y       N
# 1                  Y       N
# 2                  Y       N
# 6                  Y       N
# 7                  Y       N

# %%
# Export Merged & Cleaned CSV

final_df.to_csv("Output/brewerydb_final.csv",
                   encoding="utf-8", index=False, header=True)

# %%
brew_db = final_df.groupby(["State"])
brew_db.count().head()
# Out:
#             Brewery Name  City  Country  Year Established  Still in Business?  \
# State
# Alabama                5     5        5                 5                   5
# Alaska                 2     2        2                 2                   2
# Arizona               10    10       10                10                  10
# Arkansas               1     1        1                 1                   1
# California            70    70       70                70                  70
#
#             Closed?
# State
# Alabama           5
# Alaska            2
# Arizona          10
# Arkansas          1
# California       70

# %%
brew_c = final_df.loc[final_df["Closed?"] == "Y"]
brew_c
# Out:
#                            Brewery Name              City           State  \
# 68                            Beer Army          New Bern  North Carolina
# 75                     Beryl's Beer Co.            Denver        Colorado
# 98                           Bravo Zulu    N Williamsburg        Michigan
# 48                       Ursula Brewery            Aurora        Colorado
# 17                   Beach City Brewery  Huntington Beach      California
# 37          Rock Bridge Brewing Company          Columbia        Missouri
# 38                Bog Water Brewing Co.          Westport      Washington
# 31                    Little Egypt Beer               Ava        Illinois
# 39                Cobra Brewing Company        Lewisville           Texas
# 1                 Owl's Orchard Brewery       Queen Creek         Arizona
# 17                Sanctuary Brewing Co.      Indianapolis         Indiana
# 11           Tanglewood Branch Beer Co.      Fayetteville        Arkansas
# 13                           Mu Brewery            Aurora        Colorado
# 38                        Kilted Dragon       Garden City           Idaho
# 41                  Ornery Beer Company        Woodbridge        Virginia
# 23         Sandia Chile Grill & Brewery       Albuquerque      New Mexico
# 29         Sandia Chile Grill & Brewery       Albuquerque      New Mexico
# 39               Grateful Hands Brewing             Cabot         Vermont
# 2               Hosanna Brewing Company     Fuquay-Varina  North Carolina
# 57     New Mexico Craft Brewing Company       Albuquerque      New Mexico
# 5                      Twelve Bar Brews       Woodinville      Washington
# 6              51 North Brewing Company        Lake Orion        Michigan
# 19             Westport Brewing Company          Westport      Washington
# 37                   Aloha Beer Company          Honolulu          Hawaii
# 44          Bull Jagger Brewing Company          Portland           Maine
# 51                   Neil House Brewery          Columbus            Ohio
# 34         Lost Highway Brewing Company        Centennial        Colorado
# 45                    Stapleton Brewing            Denver        Colorado
# 49                   Raices Brewing Co.           Boulder        Colorado
# 27                 Tow Yard Brewing Co.      Indianapolis         Indiana
# 38                  Beaver View Brew Co            Albion        Nebraska
# 2                  Black Dragon Brewery          Woodland      California
# 16                         New Boundary            Cheney      Washington
# 5                 Neighborhood Beer Co.            Exeter   New Hampshire
# 24                    North Rim Brewing              Bend          Oregon
# 25         Northern Neck Brewing Compny         Reedville        Virginia
# 49              Six Row Brewing Company         St. Louis        Missouri
# 61                       OUTLAW Brewery  Lake Havasu City         Arizona
# 88                   Powder Keg Brewing             Niwot        Colorado
# 25  Seven Stills Brewery and Distillery     San Francisco      California
# 58               Twisted Manzanita Ales         San Diego      California
#
#           Country  Year Established Still in Business? Closed?
# 68  UNITED STATES              2015                  N       Y
# 75  UNITED STATES              2013                  N       Y
# 98  UNITED STATES              2013                  N       Y
# 48  UNITED STATES              2014                  N       Y
# 17  UNITED STATES              2014                  N       Y
# 37  UNITED STATES              2012                  Y       Y
# 38  UNITED STATES              2012                  N       Y
# 31  UNITED STATES              2012                  N       Y
# 39  UNITED STATES              2013                  N       Y
# 1   UNITED STATES              2013                  N       Y
# 17  UNITED STATES              2015                  N       Y
# 11  UNITED STATES              2011                  N       Y
# 13  UNITED STATES              2014                  N       Y
# 38  UNITED STATES              2011                  N       Y
# 41  UNITED STATES              2015                  N       Y
# 23  UNITED STATES              2012                  N       Y
# 29  UNITED STATES              2012                  N       Y
# 39  UNITED STATES              2012                  N       Y
# 2   UNITED STATES              2012                  N       Y
# 57  UNITED STATES              2012                  N       Y
# 5   UNITED STATES              2012                  N       Y
# 6   UNITED STATES              2013                  N       Y
# 19  UNITED STATES              2011                  N       Y
# 37  UNITED STATES              2012                  N       Y
# 44  UNITED STATES              2011                  N       Y
# 51  UNITED STATES              2009                  N       Y
# 34  UNITED STATES              2014                  N       Y
# 45  UNITED STATES              2011                  N       Y
# 49  UNITED STATES              2016                  N       Y
# 27  UNITED STATES              2014                  N       Y
# 38  UNITED STATES              2010                  N       Y
# 2   UNITED STATES              2012                  N       Y
# 16  UNITED STATES              2015                  N       Y
# 5   UNITED STATES              2015                  N       Y
# 24  UNITED STATES              2013                  Y       Y
# 25  UNITED STATES              2018                  Y       Y
# 49  UNITED STATES              2009                  N       Y
# 61  UNITED STATES              2010                  N       Y
# 88  UNITED STATES              2014                  N       Y
# 25  UNITED STATES              2012                  Y       Y
# 58  UNITED STATES              2010                  Y       Y

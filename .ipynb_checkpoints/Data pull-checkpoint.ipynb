# %%
import requests
import json
import pandas as pd

# %%
url = "https://api.brewerydb.com/v2/breweries/"
api_key = "?key=f5602f16b774b7f79ce6b916acc9000a"
new_url = url + api_key

# %%
years = []
years = pd.Series(range(2009,2011))

pages = []
pages = pd.Series(range(1,11))

indexes = []
indexes = pd.Series(range(0,50))

# %%
query_url = f"{new_url}&established="

# %%
names = []
established = []
# indexes = []
# indexes = [(0,50)]
# # pages = []
# # pages = [(1,11)]

# %%
for year in years:
    new_query = f"{query_url}{year}&p="
    for page in pages:
        response = requests.get(new_query + str(page)).json()
        for index in indexes:
            names.append(response["data"][0]["name"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-732034301717> in <module>()
#       4         response = requests.get(new_query + str(page)).json()
#       5         for index in indexes:
# ----> 6             names.append(response["data"][0]["name"])
#
# KeyError: 'data'

# %%
len(names)
# Out:
# 1000

# %%
names
# Out:
# ['16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
#  '16 Mile Brewing Company',
# ...
